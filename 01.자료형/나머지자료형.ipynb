# %%
#리스트와 튜플의 차이점은 요소를 변경하거나 삭제하거나 삽입할 수 있나 없나의 차이다 
t1 = 1,2,3
t2 = 4,5,6
t1+t2
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
l1 = [1,2,3]
l2 = [4,5,6]
l3 = l1 + l2
l3
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#딕셔너리는 요소를 변경 추가 삭제할 수 있으나 튜플이나 리스트의 인덱싱 슬라이싱은 불가능, 오직 키를 통한 밸류값 도출
#키의 값엔 리스트는 쓸 수 없으나 튜플은 사용가능
a = {'a':[1,2,3]}
a
a[2] = 'b'
a
a['name']= 'pey'
a
a[3] = [1,2,3]
a
del a[2]
a
del a['a']
a
a.values()
a.items()
# Out:
# dict_items([('name', 'pey'), (3, [1, 2, 3])])

# %%
s2 = set("hello")
s2
# Out:
# {'e', 'h', 'l', 'o'}

# %%
l1=list(s2)
l1
# Out:
# ['h', 'o', 'e', 'l']

# %%
t1=tuple(l1)
t1
# Out:
# ('h', 'o', 'e', 'l')

# %%
'python'
# Out:
# 'python'

# %%
a = [1,2,3,4]
while a:
    print(a.pop())
# Out:
# 4
# 3
# 2
# 1

# %%
if []:
    print('true')
else:
    print('false')
# Out:
# false

# %%
if [1,2,3]:
    print('true')
else:
    print('false')
# Out:
# true

# %%
bool('python')
# Out:
# True

# %%
a = [1,2,3]
id(a)
# Out:
# 5494927808

# %%
b=a
id(b)
# Out:
# 5494927808

# %%
a == b
# Out:
# True

# %%
a = [1,2,3]
b = a[:]
a[1] = 4
b
# Out:
# [1, 2, 3]

# %%
from copy import copy
a = [1,2]
b=copy(a)
b
# Out:
# [1, 2]

# %%
b is a
# Out:
# False

# %%
a,b='pyhon','life'

# %%
a,b
# Out:
# ('python', 'life')

# %%
a
# Out:
# 'pyhon'

# %%
b
# Out:
# 'life'

# %%
[a,b] = ['python','life']

# %%
a,b
# Out:
# ('python', 'life')

# %%
a=3
b=5
a,b = b,a
a
# Out:
# 5

# %%
a = [1,2,3,4]
b = [1,2,3,4]

# %%
id(a)
# Out:
# 5499585280

# %%
id(b)
# Out:
# 5499587136

# %%
a is b
# Out:
# False

# %%
d = {'국어' : 80, '영어' : 75, '수학' : 55}
d['국어'],d['영어'],d{'수학'} / 3
# Out:
#   Cell In[80], line 2
#     d['국어'],d['영어'],d{'수학'} / 3
#                      ^
# SyntaxError: invalid syntax

# %%
'국어' = 80
'영어' = 75
'수학' = 55
('국어'+'영어'+'수학')/3
# Out:
#   Cell In[82], line 1
#     '국어' = 80
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a = 80
b = 75
c = 55
(a+b+c)/3
# Out:
# 70.0

# %%
2 % 2
3 % 2
13 % 2
# Out:
# 1

# %%
pin = "881120-1068234"
yymmdd=pin[:6]

# %%
num=pin[7:]

# %%
print(yymmdd,pin[6],num)
# Out:
# 881120 - 1068234

# %%
pin.index('-')
# Out:
# 6

# %%
a = 'a:b:d:c'
b = a.replace(':','#')

# %%
b
# Out:
# 'a#b#d#c'

# %%
a = [1,3,5,4,2]
a.sort()
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a.reverse()

# %%
a
# Out:
# [5, 4, 3, 2, 1]

# %%
a = ['life','is','too','short']
result = ' '.join(a)

# %%
result
# Out:
# 'life is too short'

# %%
a = 1,2,3
a = a + (4,)
print(a)
# Out:
# (1, 2, 3, 4)

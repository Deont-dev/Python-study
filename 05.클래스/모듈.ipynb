# %%
# 모듈 : 함수가 들어가있는 py 파일 / improt는 현재 디렉터리에 있는 파일이나 파이썬 라이브러리가 저장된 디렉터리에 있는 모듈만 불러옴
'''
ex. mod1.py = def add(a,b):return a + b , sub = lambda a,b : a-b
import mod1
print (mod1.add(4,3)) > 7
print (mod1.sub(4,3)) > 1

mod1.add 이렇게 말고 함수이름만 써서 진행하고싶다면
from mod1 import * > * 전체다를 의미, 아니면 특정쓰고싶은 함수만 적으면 됨 / add, sub 이런식으로
'''

# %%
# if__name__=="__main__"의 의미
'''
만약 mod1.py 내용이 저 함수내용에다가 print(add(4,2)) 출력 명령을 해놓았을 경우엔 아마 실행하자마자 바로 더한값을 출력할 것이다.
그런데 import로 연결해서 불러낼때도 프린트값을 출력할 것이다. 이를 방지하기 위해 사용하는게 if__name__=="__main__": 다.
이 문법은 mod1.py를 직접 실행했을때는 결괏값을 출력하지만 그게 아니라면 실행되지않고 그전처럼 함수 기능만 쓸수있다.
